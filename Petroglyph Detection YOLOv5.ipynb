# %% [markdown]
# # Petroglyph Detection with YOLOv5 Model
# This notebook loads a pre-trained YOLOv5 model and predicts bounding boxes for images of petroglyphs. Trained using the YOLOv5 tutorial [notebook](https://colab.research.google.com/github/ultralytics/yolov5/blob/master/tutorial.ipynb).
#
# If running in Google Colab, make sure to upload the folder 'example_images' and the model.pt file so that your directory looks like this:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# !git clone https://github.com/ultralytics/yolov5  # clone
# %cd yolov5
# %pip install -qr requirements.txt  # install
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 15287, done.
# remote: Total 15287 (delta 0), reused 0 (delta 0), pack-reused 15287
# Receiving objects: 100% (15287/15287), 14.18 MiB | 17.80 MiB/s, done.
# Resolving deltas: 100% (10483/10483), done.
# /content/yolov5
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 184.3/184.3 KB 2.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 6.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 KB 3.9 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ipython 7.9.0 requires jedi>=0.10, which is not installed.
# cvxpy 1.2.3 requires setuptools<=64.0.2, but you have setuptools 67.4.0 which is incompatible.

# %%
# !unzip -q -u /content/example_images.zip -d /content
# ### remember to refresh the directory afterward
# Out:
# unzip:  cannot find or open /content/example_images.zip, /content/example_images.zip.zip or /content/example_images.zip.ZIP.

# %% [markdown]
# ### Run predictions
# Make sure that the folder 'example_images' is in the root directory '/content'.

# %%
### Load model and example_images from Drive
from google.colab import drive
drive.mount('/content/drive')
weights_path = '/content/drive/MyDrive/Colab Notebooks/petroglyphs/petroglyph_detection_yolov5_model.pt'
images_path = '/content/drive/MyDrive/Colab Notebooks/petroglyphs/example_images'
# Out:
# Mounted at /content/drive

# %%
# ### Or upload model and example_images directly to colab
# weights_path = '/content/petroglyph_detection_yolov5_model.pt'
# images_path = '/content/example_images'

# %%
# !python detect.py --weights "$weights_path" --img 640 --conf 0.3 --source "$images_path"
# Out:
# detect: weights=['/content/drive/MyDrive/Colab Notebooks/petroglyphs/petroglyph_detection_yolov5_model.pt'], source=/content/drive/MyDrive/Colab Notebooks/petroglyphs/example_images, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.3, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-116-g5c91dae Python-3.8.10 torch-1.13.1+cu116 CPU
#
# Fusing layers...
# Model summary: 157 layers, 7012822 parameters, 0 gradients, 15.8 GFLOPs
# image 1/3 /content/drive/MyDrive/Colab Notebooks/petroglyphs/example_images/example_panel1.jpg: 448x640 2 petroglyphs, 314.8ms
# image 2/3 /content/drive/MyDrive/Colab Notebooks/petroglyphs/example_images/example_panel2.jpg: 480x640 3 petroglyphs, 340.8ms
# ...

# %% [markdown]
# ### Display Results:

# %%
import os
from matplotlib import pyplot as plt
import matplotlib.image as mpimg
datapath = '/content/yolov5/runs/detect/exp/'

for im in [f for f in os.listdir(datapath) if f.endswith(('.jpg', 'png'))]:
  plt.figure()
  plt.imshow(mpimg.imread(datapath+im))

# %% [markdown]
# Thanks for viewing!
